# %%
import pandas as pd
data = pd.read_csv("insurance_pre.csv")
data
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
data = pd.get_dummies(data,drop_first=True)
data
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = data[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = data[['charges']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
# from sklearn.model_selection import train_test_split
# x_train , x_test , y_train , y_test = train_test_split(independent,dependent,test_size=0.3,random_state=0)
# x_train

# %%
# from sklearn.preprocessing import StandardScaler#
# sc = StandardScaler()
# x_train = sc.fit_transform(x_train)
# y_train = sc.fit_transform(y_train)

# %%
from sklearn.model_selection import GridSearchCV
# from sklearn.svm import SVR
# from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
param_grid = {'splitter':['random','best'],'criterion':['squared_error','absolute_error','friedman_mse','poisson'],'max_features':['auto','sqrt','log2']}
grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 26 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.67893941 0.66533613 0.59629885 0.67937531
#         nan        nan 0.70511429 0.69076447 0.67526698 0.65090202
#         nan        nan 0.64463662 0.69943792 0.6790644  0.71216657
#         nan        nan 0.66112841 0.6878168  0.65014851 0.66173002]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['random', 'best']},
#              verbose=3)

# %%
re = grid.cv_results_ 
print("The R_score value of the best parameter is {}:".format(grid.best_params_))
# Out:
# The R_score value of the best parameter is {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}:

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003329      0.003476         0.000000        0.000000
# 1        0.003541      0.006102         0.000000        0.000000
# 2        0.006514      0.003351         0.011390        0.011292
# 3        0.008639      0.005650         0.010279        0.011113
# 4        0.007998      0.005111         0.005532        0.004011
# 5        0.007157      0.004858         0.002703        0.005406
# 6        0.001092      0.001415         0.000000        0.000000
# 7        0.000000      0.000000         0.000000        0.000000
# 8        0.031695      0.003280         0.013214        0.016223
# 9        0.048080      0.011107         0.015944        0.013959
# 10       0.028745      0.006260         0.006198        0.005420
# 11       0.049355      0.019987         0.004913        0.005945
# 12       0.001822      0.002232         0.000000        0.000000
# 13       0.000705      0.001411         0.000000        0.000000
# 14       0.008927      0.007444         0.001798        0.002417
# 15       0.008713      0.005249         0.007559        0.006697
# 16       0.007998      0.004150         0.005979        0.002246
# 17       0.013806      0.002264         0.007428        0.006656
# 18       0.002256      0.002676         0.000000        0.000000
# 19       0.001895      0.001552         0.000000        0.000000
# 20       0.008291      0.000826         0.003868        0.002163
# 21       0.012672      0.001773         0.004312        0.001740
# 22       0.007166      0.003146         0.005187        0.003260
# 23       0.010435      0.002164         0.004340        0.002781
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto         random
# 1    squared_error               auto           best
# 2    squared_error               sqrt         random
# 3    squared_error               sqrt           best
# 4    squared_error               log2         random
# 5    squared_error               log2           best
# 6   absolute_error               auto         random
# 7   absolute_error               auto           best
# 8   absolute_error               sqrt         random
# 9   absolute_error               sqrt           best
# 10  absolute_error               log2         random
# 11  absolute_error               log2           best
# 12    friedman_mse               auto         random
# 13    friedman_mse               auto           best
# 14    friedman_mse               sqrt         random
# 15    friedman_mse               sqrt           best
# 16    friedman_mse               log2         random
# 17    friedman_mse               log2           best
# 18         poisson               auto         random
# 19         poisson               auto           best
# 20         poisson               sqrt         random
# 21         poisson               sqrt           best
# 22         poisson               log2         random
# 23         poisson               log2           best
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.636920
# 3   {'criterion': 'squared_error', 'max_features':...           0.684895
# 4   {'criterion': 'squared_error', 'max_features':...           0.629434
# 5   {'criterion': 'squared_error', 'max_features':...           0.668674
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.720441
# 9   {'criterion': 'absolute_error', 'max_features'...           0.736262
# 10  {'criterion': 'absolute_error', 'max_features'...           0.713910
# 11  {'criterion': 'absolute_error', 'max_features'...           0.694709
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.722129
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.714642
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.770970
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.763450
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.631100
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.729639
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.688155
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.787265
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.559856           0.726357           0.727331
# 3            0.408430           0.736651           0.772316
# 4            0.622941           0.670407           0.459803
# 5            0.551760           0.763400           0.753518
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.576384           0.788245           0.695994
# 9            0.623152           0.660500           0.679596
# 10           0.606823           0.715398           0.729715
# 11           0.563964           0.713140           0.578308
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.521907           0.662385           0.678291
# 15           0.626576           0.733087           0.712562
# 16           0.576402           0.616700           0.734718
# 17           0.636507           0.709105           0.746805
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.633820           0.669460           0.694468
# 21           0.672374           0.715266           0.723365
# 22           0.550607           0.696602           0.695479
# 23           0.592638           0.723907           0.506132
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.744233         0.678939        0.070427                8
# 3            0.724388         0.665336        0.131454               10
# 4            0.598910         0.596299        0.072025               16
# 5            0.659525         0.679375        0.076618                6
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.744507         0.705114        0.071207                2
# 9            0.754312         0.690764        0.048416                4
# 10           0.610489         0.675267        0.054679                9
# 11           0.704389         0.650902        0.065546               13
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.638471         0.644637        0.067161               15
# 15           0.710323         0.699438        0.037317                3
# 16           0.696531         0.679064        0.072495                7
# 17           0.704966         0.712167        0.043853                1
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.676794         0.661128        0.024794               12
# 21           0.598440         0.687817        0.048976                5
# 22           0.619899         0.650149        0.057412               14
# 23           0.698708         0.661730        0.099977               11

# %%
# from sklearn.svm import SVR
# regressor = SVR(kernel="poly" , C=3000,gamma="scale")
# regressor.fit(x_train,y_train)

# %%
# y_pred = regressor.predict(x_test)

# from sklearn.metrics import r2_score
# score = r2_score(y_test,y_pred)
# score
